# %% [markdown]
# # Convolutional Neural Networks
# ---
# In this notebook, we train a **CNN** to classify images from the CIFAR-10 database.
#
# The images in this database are small color images that fall into one of ten classes; some example images are pictured below.
#
# <img src='notebook_ims/cifar_data.png' width=70% height=70% />

# %% [markdown]
# ### Test for [CUDA](http://pytorch.org/docs/stable/cuda.html)
#
# Since these are larger (32x32x3) images, it may prove useful to speed up your training time by using a GPU. CUDA is a parallel computing platform and CUDA Tensors are the same as typical Tensors, only they utilize GPU's for computation.

# %%
import torch
import numpy as np

# check if CUDA is available
train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
    print('CUDA is not available.  Training on CPU ...')
else:
    print('CUDA is available!  Training on GPU ...')
# Out:
# CUDA is available!  Training on GPU ...

# %% [markdown]
# ---
# ## Load the [Data](http://pytorch.org/docs/stable/torchvision/datasets.html)
#
# Downloading may take a minute. We load in the training and test data, split the training data into a training and validation set, then create DataLoaders for each of these sets of data.

# %%
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data.sampler import SubsetRandomSampler

# number of subprocesses to use for data loading
num_workers = 0
# how many samples per batch to load
batch_size = 20
# percentage of training set to use as validation
valid_size = 0.2

# convert data to a normalized torch.FloatTensor
transform = transforms.Compose([transforms.RandomRotation(10),
                                transforms.RandomHorizontalFlip(),
                                transforms.ToTensor(),
                                transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
                                ])

# choose the training and test datasets
train_data = datasets.CIFAR10('data', train=True,
                              download=True, transform=transform)
test_data = datasets.CIFAR10('data', train=False,
                             download=True, transform=transform)

# obtain training indices that will be used for validation
num_train = len(train_data)
indices = list(range(num_train))
np.random.shuffle(indices)
split = int(np.floor(valid_size * num_train))
train_idx, valid_idx = indices[split:], indices[:split]

# define samplers for obtaining training and validation batches
train_sampler = SubsetRandomSampler(train_idx)
valid_sampler = SubsetRandomSampler(valid_idx)

# prepare data loaders (combine dataset and sampler)
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size,
    sampler=train_sampler, num_workers=num_workers)
valid_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, 
    sampler=valid_sampler, num_workers=num_workers)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size, 
    num_workers=num_workers, shuffle=True)

# specify the image classes
classes = ['airplane', 'automobile', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck']
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# ### Visualize a Batch of Training Data

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# helper function to un-normalize and display an image
def imshow(img):
    img = img / 2 + 0.5  # unnormalize
    plt.imshow(np.transpose(img, (1, 2, 0)))  # convert from Tensor image

# %%
# obtain one batch of training images
dataiter = iter(train_loader)
images, labels = dataiter.next()
images = images.numpy() # convert images to numpy for display

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(12, 10))
# display 20 images
for idx in np.arange(20):
    ax = fig.add_subplot(4, 20/4, idx+1, xticks=[], yticks=[])
    imshow(images[idx])
    ax.set_title(classes[labels[idx]])

# %%
print(images.shape)
# Out:
# (20, 3, 32, 32)

# %% [markdown]
# ### View an Image in More Detail
#
# Here, we look at the normalized red, green, and blue (RGB) color channels as three separate, grayscale intensity images.

# %%
rgb_img = np.squeeze(images[3])
channels = ['red channel', 'green channel', 'blue channel']

fig = plt.figure(figsize = (36, 36)) 
for idx in np.arange(rgb_img.shape[0]):
    ax = fig.add_subplot(1, 3, idx + 1)
    img = rgb_img[idx]
    ax.imshow(img, cmap='gray')
    ax.set_title(channels[idx])
    width, height = img.shape
    thresh = img.max()/2.5
    for x in range(width):
        for y in range(height):
            val = round(img[x][y],2) if img[x][y] !=0 else 0
            ax.annotate(str(val), xy=(y,x),
                    horizontalalignment='center',
                    verticalalignment='center', size=8,
                    color='white' if img[x][y]<thresh else 'black')

# %% [markdown]
# ---
# ## Define the Network [Architecture](http://pytorch.org/docs/stable/nn.html)
#
# This time, you'll define a CNN architecture. Instead of an MLP, which used linear, fully-connected layers, you'll use the following:
# * [Convolutional layers](https://pytorch.org/docs/stable/nn.html#conv2d), which can be thought of as stack of filtered images.
# * [Maxpooling layers](https://pytorch.org/docs/stable/nn.html#maxpool2d), which reduce the x-y size of an input, keeping only the most _active_ pixels from the previous layer.
# * The usual Linear + Dropout layers to avoid overfitting and produce a 10-dim output.
#
# A network with 2 convolutional layers is shown in the image below and in the code, and you've been given starter code with one convolutional and one maxpooling layer.
#
# <img src='notebook_ims/2_layer_conv.png' height=50% width=50% />
#
# #### TODO: Define a model with multiple convolutional layers, and define the feedforward metwork behavior.
#
# The more convolutional layers you include, the more complex patterns in color and shape a model can detect. It's suggested that your final model include 2 or 3 convolutional layers as well as linear layers + dropout in between to avoid overfitting.
#
# It's good practice to look at existing research and implementations of related models as a starting point for defining your own models. You may find it useful to look at [this PyTorch classification example](https://github.com/pytorch/tutorials/blob/master/beginner_source/blitz/cifar10_tutorial.py) or [this, more complex Keras example](https://github.com/keras-team/keras/blob/master/examples/cifar10_cnn.py) to help decide on a final structure.
#
# #### Output volume for a convolutional layer
#
# To compute the output size of a given convolutional layer we can perform the following calculation (taken from [Stanford's cs231n course](http://cs231n.github.io/convolutional-networks/#layers)):
# > We can compute the spatial size of the output volume as a function of the input volume size (W), the kernel/filter size (F), the stride with which they are applied (S), and the amount of zero padding used (P) on the border. The correct formula for calculating how many neurons define the output_W is given by `(W−F+2P)/S+1`.
#
# For example for a 7x7 input and a 3x3 filter with stride 1 and pad 0 we would get a 5x5 output. With stride 2 we would get a 3x3 output.

# %%
import torch.nn as nn
import torch.nn.functional as F

# define the CNN architecture
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()

        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, padding=1) # convolutional layer (sees 32x32x3 image tensor)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, padding=1) # convolutional layer (sees 16x16x16 tensor)
        self.conv3 = nn.Conv2d(32, 64, kernel_size=3, padding=1) # convolutional layer (sees 8x8x32 tensor)
        self.pool = nn.MaxPool2d(2, 2) # max pooling layer
        self.drop2d = nn.Dropout2d(0.1)
        self.fc1 = nn.Linear(64*4*4, 500) # densely connected layer
        self.fc2 = nn.Linear(500, 10)
        self.dropout = nn.Dropout(0.2)

    def forward(self, x):
        # add sequence of convolutional and max pooling layers
        x = self.pool(F.relu(self.drop2d(self.conv1(x))))
        x = self.pool(F.relu(self.drop2d(self.conv2(x))))
        x = self.pool(F.relu(self.drop2d(self.conv3(x))))
        x = x.view(-1, 64*4*4)
        x = self.dropout(x)
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# create a complete CNN
model = Net()
print(model)

# move tensors to GPU if CUDA is available
if train_on_gpu:
    model.cuda()
# Out:
# Net(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (drop2d): Dropout2d(p=0.1)
#   (fc1): Linear(in_features=1024, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
#   (dropout): Dropout(p=0.1)
# )

# %% [markdown]
# ### Specify [Loss Function](http://pytorch.org/docs/stable/nn.html#loss-functions) and [Optimizer](http://pytorch.org/docs/stable/optim.html)
#
# Decide on a loss and optimization function that is best suited for this classification task. The linked code examples from above, may be a good starting point; [this PyTorch classification example](https://github.com/pytorch/tutorials/blob/master/beginner_source/blitz/cifar10_tutorial.py) or [this, more complex Keras example](https://github.com/keras-team/keras/blob/master/examples/cifar10_cnn.py). Pay close attention to the value for **learning rate** as this value determines how your model converges to a small error.
#
# #### TODO: Define the loss and optimizer and see how these choices change the loss over time.

# %%
import torch.optim as optim

# specify loss function
criterion = nn.CrossEntropyLoss()

# specify optimizer
#optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)
optimizer = optim.SGD(model.parameters(), lr=0.01)

# %% [markdown]
# ---
# ## Train the Network
#
# Remember to look at how the training and validation loss decreases over time; if the validation loss ever increases it indicates possible overfitting.

# %%
# number of epochs to train the model
n_epochs = 50 # you may increase this number to train a final model

valid_loss_min = np.Inf # track change in validation loss

for epoch in range(1, n_epochs+1):

    # keep track of training and validation loss
    train_loss = 0.0
    valid_loss = 0.0
    
    ###################
    # train the model #
    ###################
    model.train()
    for data, target in train_loader:
        # move tensors to GPU if CUDA is available
        if train_on_gpu:
            data, target = data.cuda(), target.cuda()
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the batch loss
        loss = criterion(output, target)
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update training loss
        train_loss += loss.item()*data.size(0)
        
    ######################    
    # validate the model #
    ######################
    model.eval()
    for data, target in valid_loader:
        # move tensors to GPU if CUDA is available
        if train_on_gpu:
            data, target = data.cuda(), target.cuda()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the batch loss
        loss = criterion(output, target)
        # update average validation loss 
        valid_loss += loss.item()*data.size(0)
    
    # calculate average losses
    train_loss = train_loss/len(train_loader.dataset)
    valid_loss = valid_loss/len(valid_loader.dataset)
        
    # print training/validation statistics 
    print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
        epoch, train_loss, valid_loss))
    
    # save model if validation loss has decreased
    if valid_loss <= valid_loss_min:
        print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
        valid_loss_min,
        valid_loss))
        torch.save(model.state_dict(), 'model_cifar_exercise.pt')
        valid_loss_min = valid_loss
# Out:
# Epoch: 1 	Training Loss: 1.708266 	Validation Loss: 0.377242
# Validation loss decreased (inf --> 0.377242).  Saving model ...
# Epoch: 2 	Training Loss: 1.457133 	Validation Loss: 0.330123
# Validation loss decreased (0.377242 --> 0.330123).  Saving model ...
# Epoch: 3 	Training Loss: 1.335943 	Validation Loss: 0.303820
# Validation loss decreased (0.330123 --> 0.303820).  Saving model ...
# Epoch: 4 	Training Loss: 1.262608 	Validation Loss: 0.289863
# Validation loss decreased (0.303820 --> 0.289863).  Saving model ...
# Epoch: 5 	Training Loss: 1.208490 	Validation Loss: 0.276851
# Validation loss decreased (0.289863 --> 0.276851).  Saving model ...
# Epoch: 6 	Training Loss: 1.164637 	Validation Loss: 0.267120
# Validation loss decreased (0.276851 --> 0.267120).  Saving model ...
# Epoch: 7 	Training Loss: 1.134106 	Validation Loss: 0.257795
# Validation loss decreased (0.267120 --> 0.257795).  Saving model ...
# Epoch: 8 	Training Loss: 1.100885 	Validation Loss: 0.252005
# Validation loss decreased (0.257795 --> 0.252005).  Saving model ...
# Epoch: 9 	Training Loss: 1.074017 	Validation Loss: 0.242360
# Validation loss decreased (0.252005 --> 0.242360).  Saving model ...
# Epoch: 10 	Training Loss: 1.053030 	Validation Loss: 0.239922
# Validation loss decreased (0.242360 --> 0.239922).  Saving model ...
# Epoch: 11 	Training Loss: 1.030803 	Validation Loss: 0.233887
# Validation loss decreased (0.239922 --> 0.233887).  Saving model ...
# Epoch: 12 	Training Loss: 1.006562 	Validation Loss: 0.229047
# Validation loss decreased (0.233887 --> 0.229047).  Saving model ...
# Epoch: 13 	Training Loss: 0.989269 	Validation Loss: 0.223370
# Validation loss decreased (0.229047 --> 0.223370).  Saving model ...
# Epoch: 14 	Training Loss: 0.974674 	Validation Loss: 0.224073
# Epoch: 15 	Training Loss: 0.955055 	Validation Loss: 0.214040
# Validation loss decreased (0.223370 --> 0.214040).  Saving model ...
# Epoch: 16 	Training Loss: 0.939184 	Validation Loss: 0.212052
# Validation loss decreased (0.214040 --> 0.212052).  Saving model ...
# Epoch: 17 	Training Loss: 0.928777 	Validation Loss: 0.206444
# Validation loss decreased (0.212052 --> 0.206444).  Saving model ...
# Epoch: 18 	Training Loss: 0.912614 	Validation Loss: 0.206108
# Validation loss decreased (0.206444 --> 0.206108).  Saving model ...
# Epoch: 19 	Training Loss: 0.898034 	Validation Loss: 0.202950
# Validation loss decreased (0.206108 --> 0.202950).  Saving model ...
# Epoch: 20 	Training Loss: 0.890470 	Validation Loss: 0.202968
# Epoch: 21 	Training Loss: 0.879093 	Validation Loss: 0.198988
# Validation loss decreased (0.202950 --> 0.198988).  Saving model ...
# Epoch: 22 	Training Loss: 0.867430 	Validation Loss: 0.194852
# Validation loss decreased (0.198988 --> 0.194852).  Saving model ...
# Epoch: 23 	Training Loss: 0.850302 	Validation Loss: 0.192692
# Validation loss decreased (0.194852 --> 0.192692).  Saving model ...
# Epoch: 24 	Training Loss: 0.843742 	Validation Loss: 0.189317
# Validation loss decreased (0.192692 --> 0.189317).  Saving model ...
# Epoch: 25 	Training Loss: 0.835535 	Validation Loss: 0.188395
# Validation loss decreased (0.189317 --> 0.188395).  Saving model ...
# Epoch: 26 	Training Loss: 0.831074 	Validation Loss: 0.186082
# Validation loss decreased (0.188395 --> 0.186082).  Saving model ...
# Epoch: 27 	Training Loss: 0.816203 	Validation Loss: 0.182653
# Validation loss decreased (0.186082 --> 0.182653).  Saving model ...
# Epoch: 28 	Training Loss: 0.809161 	Validation Loss: 0.178780
# Validation loss decreased (0.182653 --> 0.178780).  Saving model ...
# Epoch: 29 	Training Loss: 0.805227 	Validation Loss: 0.179273
# Epoch: 30 	Training Loss: 0.796258 	Validation Loss: 0.179199
# Epoch: 31 	Training Loss: 0.786495 	Validation Loss: 0.178037
# Validation loss decreased (0.178780 --> 0.178037).  Saving model ...
# Epoch: 32 	Training Loss: 0.783759 	Validation Loss: 0.179815
# Epoch: 33 	Training Loss: 0.777467 	Validation Loss: 0.177018
# Validation loss decreased (0.178037 --> 0.177018).  Saving model ...
# Epoch: 34 	Training Loss: 0.767824 	Validation Loss: 0.170481
# Validation loss decreased (0.177018 --> 0.170481).  Saving model ...
# Epoch: 35 	Training Loss: 0.763689 	Validation Loss: 0.171623
# Epoch: 36 	Training Loss: 0.758164 	Validation Loss: 0.170621
# Epoch: 37 	Training Loss: 0.750694 	Validation Loss: 0.170288
# Validation loss decreased (0.170481 --> 0.170288).  Saving model ...
# Epoch: 38 	Training Loss: 0.743989 	Validation Loss: 0.168435
# Validation loss decreased (0.170288 --> 0.168435).  Saving model ...
# Epoch: 39 	Training Loss: 0.741636 	Validation Loss: 0.168574
# Epoch: 40 	Training Loss: 0.729689 	Validation Loss: 0.164285
# Validation loss decreased (0.168435 --> 0.164285).  Saving model ...
# Epoch: 41 	Training Loss: 0.729931 	Validation Loss: 0.164502
# Epoch: 42 	Training Loss: 0.720729 	Validation Loss: 0.163875
# Validation loss decreased (0.164285 --> 0.163875).  Saving model ...
# Epoch: 43 	Training Loss: 0.714623 	Validation Loss: 0.164484
# Epoch: 44 	Training Loss: 0.714213 	Validation Loss: 0.161525
# Validation loss decreased (0.163875 --> 0.161525).  Saving model ...
# Epoch: 45 	Training Loss: 0.708512 	Validation Loss: 0.158291
# Validation loss decreased (0.161525 --> 0.158291).  Saving model ...
# Epoch: 46 	Training Loss: 0.704463 	Validation Loss: 0.161288
# Epoch: 47 	Training Loss: 0.696022 	Validation Loss: 0.159171
# Epoch: 48 	Training Loss: 0.696103 	Validation Loss: 0.160123
# Epoch: 49 	Training Loss: 0.690934 	Validation Loss: 0.157196
# Validation loss decreased (0.158291 --> 0.157196).  Saving model ...
# Epoch: 50 	Training Loss: 0.684665 	Validation Loss: 0.156108
# Validation loss decreased (0.157196 --> 0.156108).  Saving model ...
# Epoch: 51 	Training Loss: 0.681970 	Validation Loss: 0.154382
# Validation loss decreased (0.156108 --> 0.154382).  Saving model ...
# Epoch: 52 	Training Loss: 0.681298 	Validation Loss: 0.155324
# Epoch: 53 	Training Loss: 0.676741 	Validation Loss: 0.155278
# Epoch: 54 	Training Loss: 0.675163 	Validation Loss: 0.155282
# Epoch: 55 	Training Loss: 0.667632 	Validation Loss: 0.153112
# Validation loss decreased (0.154382 --> 0.153112).  Saving model ...
# Epoch: 56 	Training Loss: 0.662062 	Validation Loss: 0.153397
# Epoch: 57 	Training Loss: 0.661101 	Validation Loss: 0.154427
# Epoch: 58 	Training Loss: 0.656443 	Validation Loss: 0.152654
# Validation loss decreased (0.153112 --> 0.152654).  Saving model ...
# Epoch: 59 	Training Loss: 0.656062 	Validation Loss: 0.150861
# Validation loss decreased (0.152654 --> 0.150861).  Saving model ...
# Epoch: 60 	Training Loss: 0.652769 	Validation Loss: 0.149917
# Validation loss decreased (0.150861 --> 0.149917).  Saving model ...
# Epoch: 61 	Training Loss: 0.645963 	Validation Loss: 0.152520
# Epoch: 62 	Training Loss: 0.645405 	Validation Loss: 0.152449
# Epoch: 63 	Training Loss: 0.640902 	Validation Loss: 0.150105
# Epoch: 64 	Training Loss: 0.639931 	Validation Loss: 0.149042
# Validation loss decreased (0.149917 --> 0.149042).  Saving model ...
# Epoch: 65 	Training Loss: 0.634471 	Validation Loss: 0.149186
# Epoch: 66 	Training Loss: 0.634842 	Validation Loss: 0.148155
# Validation loss decreased (0.149042 --> 0.148155).  Saving model ...
# Epoch: 67 	Training Loss: 0.635589 	Validation Loss: 0.147472
# Validation loss decreased (0.148155 --> 0.147472).  Saving model ...
# Epoch: 68 	Training Loss: 0.623913 	Validation Loss: 0.147344
# Validation loss decreased (0.147472 --> 0.147344).  Saving model ...
# Epoch: 69 	Training Loss: 0.623805 	Validation Loss: 0.147260
# Validation loss decreased (0.147344 --> 0.147260).  Saving model ...
# Epoch: 70 	Training Loss: 0.618690 	Validation Loss: 0.144893
# Validation loss decreased (0.147260 --> 0.144893).  Saving model ...
# Epoch: 71 	Training Loss: 0.624364 	Validation Loss: 0.146191
# Epoch: 72 	Training Loss: 0.615971 	Validation Loss: 0.144025
# Validation loss decreased (0.144893 --> 0.144025).  Saving model ...
# Epoch: 73 	Training Loss: 0.612282 	Validation Loss: 0.145386
# Epoch: 74 	Training Loss: 0.615669 	Validation Loss: 0.143820
# Validation loss decreased (0.144025 --> 0.143820).  Saving model ...
# Epoch: 75 	Training Loss: 0.613976 	Validation Loss: 0.145862
# Epoch: 76 	Training Loss: 0.612089 	Validation Loss: 0.143545
# Validation loss decreased (0.143820 --> 0.143545).  Saving model ...
# Epoch: 77 	Training Loss: 0.608415 	Validation Loss: 0.143003
# Validation loss decreased (0.143545 --> 0.143003).  Saving model ...
# Epoch: 78 	Training Loss: 0.608259 	Validation Loss: 0.144466
# Epoch: 79 	Training Loss: 0.602484 	Validation Loss: 0.143949
# Epoch: 80 	Training Loss: 0.598339 	Validation Loss: 0.147115
# Epoch: 81 	Training Loss: 0.601239 	Validation Loss: 0.142302
# Validation loss decreased (0.143003 --> 0.142302).  Saving model ...
# Epoch: 82 	Training Loss: 0.595335 	Validation Loss: 0.142231
# Validation loss decreased (0.142302 --> 0.142231).  Saving model ...
# Epoch: 83 	Training Loss: 0.588721 	Validation Loss: 0.140817
# Validation loss decreased (0.142231 --> 0.140817).  Saving model ...
# Epoch: 84 	Training Loss: 0.592655 	Validation Loss: 0.141614
# Epoch: 85 	Training Loss: 0.592118 	Validation Loss: 0.141459
# Epoch: 86 	Training Loss: 0.592065 	Validation Loss: 0.141628
# Epoch: 87 	Training Loss: 0.589773 	Validation Loss: 0.141615
# Epoch: 88 	Training Loss: 0.578272 	Validation Loss: 0.143871
# Epoch: 89 	Training Loss: 0.584086 	Validation Loss: 0.141410
# Epoch: 90 	Training Loss: 0.581170 	Validation Loss: 0.143800
# Epoch: 91 	Training Loss: 0.576813 	Validation Loss: 0.142643
# Epoch: 92 	Training Loss: 0.577494 	Validation Loss: 0.140653
# Validation loss decreased (0.140817 --> 0.140653).  Saving model ...
# Epoch: 93 	Training Loss: 0.574194 	Validation Loss: 0.139710
# Validation loss decreased (0.140653 --> 0.139710).  Saving model ...
# Epoch: 94 	Training Loss: 0.577932 	Validation Loss: 0.142585
# Epoch: 95 	Training Loss: 0.573456 	Validation Loss: 0.140648
# Epoch: 96 	Training Loss: 0.570612 	Validation Loss: 0.140007
# Epoch: 97 	Training Loss: 0.571134 	Validation Loss: 0.140896
# Epoch: 98 	Training Loss: 0.565224 	Validation Loss: 0.140564
# Epoch: 99 	Training Loss: 0.558440 	Validation Loss: 0.138402
# Validation loss decreased (0.139710 --> 0.138402).  Saving model ...
# Epoch: 100 	Training Loss: 0.560247 	Validation Loss: 0.138624
# Epoch: 101 	Training Loss: 0.564830 	Validation Loss: 0.141393
# Epoch: 102 	Training Loss: 0.565539 	Validation Loss: 0.138557
# Epoch: 103 	Training Loss: 0.558699 	Validation Loss: 0.137951
# Validation loss decreased (0.138402 --> 0.137951).  Saving model ...
# Epoch: 104 	Training Loss: 0.559918 	Validation Loss: 0.141630
# Epoch: 105 	Training Loss: 0.560827 	Validation Loss: 0.140774
# Epoch: 106 	Training Loss: 0.551806 	Validation Loss: 0.141592
# Epoch: 107 	Training Loss: 0.557020 	Validation Loss: 0.140917
# Epoch: 108 	Training Loss: 0.552584 	Validation Loss: 0.140454
# Epoch: 109 	Training Loss: 0.553179 	Validation Loss: 0.137527
# Validation loss decreased (0.137951 --> 0.137527).  Saving model ...
# Epoch: 110 	Training Loss: 0.549020 	Validation Loss: 0.138546
# Epoch: 111 	Training Loss: 0.546934 	Validation Loss: 0.138626
# Epoch: 112 	Training Loss: 0.545808 	Validation Loss: 0.139284
# Epoch: 113 	Training Loss: 0.548139 	Validation Loss: 0.137339
# Validation loss decreased (0.137527 --> 0.137339).  Saving model ...
# Epoch: 114 	Training Loss: 0.544955 	Validation Loss: 0.141473
# Epoch: 115 	Training Loss: 0.542030 	Validation Loss: 0.137931
# Epoch: 116 	Training Loss: 0.540096 	Validation Loss: 0.138572
# Epoch: 117 	Training Loss: 0.540034 	Validation Loss: 0.136376
# Validation loss decreased (0.137339 --> 0.136376).  Saving model ...
# Epoch: 118 	Training Loss: 0.540072 	Validation Loss: 0.138907
# Epoch: 119 	Training Loss: 0.536676 	Validation Loss: 0.136939
# Epoch: 120 	Training Loss: 0.538479 	Validation Loss: 0.138455

# %% [markdown]
# ###  Load the Model with the Lowest Validation Loss

# %%
model.load_state_dict(torch.load('model_cifar_exercise.pt'))

# %% [markdown]
# ---
# ## Test the Trained Network
#
# Test your trained model on previously unseen data! A "good" result will be a CNN that gets around 70% (or more, try your best!) accuracy on these test images.

# %%
# track test loss
test_loss = 0.0
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))

model.eval()
# iterate over test data
for data, target in test_loader:
    # move tensors to GPU if CUDA is available
    if train_on_gpu:
        data, target = data.cuda(), target.cuda()
    # forward pass: compute predicted outputs by passing inputs to the model
    output = model(data)
    # calculate the batch loss
    loss = criterion(output, target)
    # update test loss 
    test_loss += loss.item()*data.size(0)
    # convert output probabilities to predicted class
    _, pred = torch.max(output, 1)    
    # compare predictions to true label
    correct_tensor = pred.eq(target.data.view_as(pred))
    correct = np.squeeze(correct_tensor.numpy()) if not train_on_gpu else np.squeeze(correct_tensor.cpu().numpy())
    # calculate test accuracy for each object class
    for i in range(batch_size):
        label = target.data[i]
        class_correct[label] += correct[i].item()
        class_total[label] += 1

# average test loss
test_loss = test_loss/len(test_loader.dataset)
print('Test Loss: {:.6f}\n'.format(test_loss))

for i in range(10):
    if class_total[i] > 0:
        print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
            classes[i], 100 * class_correct[i] / class_total[i],
            np.sum(class_correct[i]), np.sum(class_total[i])))
    else:
        print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))

print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
    100. * np.sum(class_correct) / np.sum(class_total),
    np.sum(class_correct), np.sum(class_total)))
# Out:
# Test Loss: 0.716522
#
# Test Accuracy of airplane: 80% (807/1000)
# Test Accuracy of automobile: 84% (847/1000)
# Test Accuracy of  bird: 63% (638/1000)
# Test Accuracy of   cat: 60% (604/1000)
# Test Accuracy of  deer: 75% (759/1000)
# Test Accuracy of   dog: 62% (620/1000)
# Test Accuracy of  frog: 82% (824/1000)
# Test Accuracy of horse: 82% (821/1000)
# Test Accuracy of  ship: 83% (832/1000)
# Test Accuracy of truck: 81% (811/1000)
#
# Test Accuracy (Overall): 75% (7563/10000)

# %% [markdown]
# ### Question: What are your model's weaknesses and how might they be improved?

# %% [markdown]
# **Answer**:
# 1. Test Accuracy (Overall): 61% (6168/10000)
#     1. My model used nn.Conv2d(3, 16, 3, padding=1), kernel size = 3; the solution uses 5.
#     2. My model had 3 conrevolutional layers; the solution has 3.
#     3. My model didn't have dropout function; the solution doesn't either.
#     4. Thy optimizer of my model set learning rate at 0.001, optim.SGD(model.parameters(), lr=0.001); the solution sets 0.01.
#     5. Maybe the training data set is too small.
# 2. Test Accuracy (Overall): 73% (7347/10000)
#     1. I changed the model architecture to be the same with the solution and got higher accuracy.
#     2. However in the validation I got 5 errors (more than previously 3); the solution 75% got 0 error.
#     3. Is it over-fitted? Add nn.Dropout2D()?

# %% [markdown]
# ### Visualize Sample Test Results

# %%
# obtain one batch of test images
dataiter = iter(test_loader)
images, labels = dataiter.next()
images.numpy()

# move model inputs to cuda, if GPU available
if train_on_gpu:
    images = images.cuda()

# get sample outputs
output = model(images)
# convert output probabilities to predicted class
_, preds_tensor = torch.max(output, 1)
preds = np.squeeze(preds_tensor.numpy()) if not train_on_gpu else np.squeeze(preds_tensor.cpu().numpy())

# plot the images in the batch, along with predicted and true labels
fig = plt.figure(figsize=(25, 4))
for idx in np.arange(20):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])
    ax.set_title("{} ({})".format(classes[preds[idx]], classes[labels[idx]]),
                 color=("green" if preds[idx]==labels[idx].item() else "red"))
